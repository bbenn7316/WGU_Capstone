# %% [markdown]
# # ML Project For Predicting Game Success Based On Genre

# %% [markdown]
# ## Loading Data

# %%
from Data_Model_Creation import *
from Data_Load_Preprocess import *
from User_Interface import *

df = read_convert_json_dataset()
cleanup_df(df)
root = Tk()
model_ui(root, df).run()

# %% [markdown]
# ## Preparing Data

# %% [markdown]
# ### Data Cleaning

# %%
cleanup_df(df)
df.info()

# %%
root = Tk()
model_ui(root, df).run()

# %% [markdown]
# ### Data Separation

# %% [markdown]
# ## Creating Linear Regression Model
